# %% [markdown]
# Finding Habitable Exoplanets

# %% [markdown]
# Using Planetary Dataset by Caltech-NASA to visualize detection of Planetary Systems detected

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Visualizes all the columns
pd.set_option('display.max_columns', None)

# %%
#Import dataset
df = pd.read_csv('exoplanet.csv')

#Print the shape of the dataset
print(df.shape)

#Select the top of the dataset
df.head()
# Out:
# (5211, 84)
#       pl_name  hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0    11 Com b    11 Com        2        1  Radial Velocity       2007
# 1    11 UMi b    11 UMi        1        1  Radial Velocity       2009
# 2    14 And b    14 And        1        1  Radial Velocity       2008
# 3    14 Her b    14 Her        1        2  Radial Velocity       2002
# 4  16 Cyg B b  16 Cyg B        3        1  Radial Velocity       1996
#
#                             disc_facility  pl_controv_flag    pl_orbper  \
# 0                        Xinglong Station                0   326.030000
# 1  Thueringer Landessternwarte Tautenburg                0   516.219970
# 2       Okayama Astrophysical Observatory                0   185.840000
# 3                  W. M. Keck Observatory                0  1765.038901
# 4                  Multiple Observatories                0   798.500000
#
#    pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbsmax  pl_orbsmaxerr1  \
# ...

# %%
#Analysing the type of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5211 entries, 0 to 5210
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          5211 non-null   object
#  1   hostname         5211 non-null   object
#  2   sy_snum          5211 non-null   int64
#  3   sy_pnum          5211 non-null   int64
#  4   discoverymethod  5211 non-null   object
#  5   disc_year        5211 non-null   int64
#  6   disc_facility    5211 non-null   object
#  7   pl_controv_flag  5211 non-null   int64
#  8   pl_orbper        5031 non-null   float64
#  9   pl_orbpererr1    4538 non-null   float64
#  10  pl_orbpererr2    4538 non-null   float64
#  11  pl_orbperlim     5031 non-null   float64
#  12  pl_orbsmax       4937 non-null   float64
#  13  pl_orbsmaxerr1   2385 non-null   float64
#  14  pl_orbsmaxerr2   2385 non-null   float64
#  15  pl_orbsmaxlim    4938 non-null   float64
# ...

# %%
#Checking for NULL values
df.isna().any()
# Out:
# pl_name            False
# hostname           False
# sy_snum            False
# sy_pnum            False
# discoverymethod    False
#                    ...
# sy_kmagerr1         True
# sy_kmagerr2         True
# sy_gaiamag          True
# sy_gaiamagerr1      True
# sy_gaiamagerr2      True
# Length: 84, dtype: bool

# %%
#Replaceing NULL values from dataset with Nan
missing_values=['??','na','X','999999']
df=df.replace(missing_values,np.NaN)

# %%
#Checking shape post removal of NULL values
df.shape
# Out:
# (5211, 84)

# %%
df.head()
# Out:
#       pl_name  hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0    11 Com b    11 Com        2        1  Radial Velocity       2007
# 1    11 UMi b    11 UMi        1        1  Radial Velocity       2009
# 2    14 And b    14 And        1        1  Radial Velocity       2008
# 3    14 Her b    14 Her        1        2  Radial Velocity       2002
# 4  16 Cyg B b  16 Cyg B        3        1  Radial Velocity       1996
#
#                             disc_facility  pl_controv_flag    pl_orbper  \
# 0                        Xinglong Station                0   326.030000
# 1  Thueringer Landessternwarte Tautenburg                0   516.219970
# 2       Okayama Astrophysical Observatory                0   185.840000
# 3                  W. M. Keck Observatory                0  1765.038901
# 4                  Multiple Observatories                0   798.500000
#
#    pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbsmax  pl_orbsmaxerr1  \
# ...

# %%
df1= df.loc[df['discoverymethod'] == 'Radial Velocity']
df2= df.loc[df['discoverymethod'] == 'Transits']
df3= df.loc[df['discoverymethod'] == 'Microlensing']
df4= df.loc[df['discoverymethod'] == 'Imaging']
df5= df.loc[df['discoverymethod'] == 'Timing Variations']
df6= df.loc[df['discoverymethod'] == 'Orbital Brightness Modulation']
df7= df.loc[df['discoverymethod'] == 'Astrometry']

Y3 = df3['pl_bmassj']
X3= df3['pl_orbper']

Y1 = df1['pl_bmassj']
X1= df1['pl_orbper']

Y2 = df2['pl_bmassj']
X2= df2['pl_orbper']

Y4 = df4['pl_bmassj']
X4= df4['pl_orbper']

Y5 = df5['pl_bmassj']
X5= df5['pl_orbper']

Y6 = df6['pl_bmassj']
X6= df6['pl_orbper']

Y7 = df7['pl_bmassj']
X7= df7['pl_orbper']

# %%
#Plotting a scatter plot

label1= ['Radial Velocity','Transits','Microlensing','Imaging','Timing Varitions','Orbital Brightness Modulation','Astrometry']
plt.scatter(X1,Y1,marker='.',color='red',label='Radial Velocity')
plt.scatter(X2,Y2,marker='o',color='blue',label='Transits')
plt.scatter(X3,Y3,marker='x',color='green',label='Microlensing')
plt.scatter(X4,Y4,marker='+',color='orange',label='Imaging')
plt.scatter(X5,Y5,marker='*',color='purple',label='Timimng Variations')
plt.scatter(X6,Y6,marker='.',color='black',label='Orbital Brightness Modulation')
plt.scatter(X7,Y7,marker='+',color='cyan',label='Astrometry')
plt.yscale(value='log')
plt.ylim(0.1,100)
plt.xlim(0.1,10**10)
plt.legend()
plt.xscale(value='log')
plt.title('Planet Mass v. Orbital Period')
plt.xlabel('Orbital Period [days]')
plt.ylabel('Planet Mass or M*sin(i) [Jupiter masses]')
# Out:
# Text(0, 0.5, 'Planet Mass or M*sin(i) [Jupiter masses]')

# %%
df1= df.loc[df['discoverymethod'] == 'Radial Velocity']
df2= df.loc[df['discoverymethod'] == 'Transits']
df3= df.loc[df['discoverymethod'] == 'Microlensing']
df4= df.loc[df['discoverymethod'] == 'Imaging']
df5= df.loc[df['discoverymethod'] == 'Timing Variations']
df6= df.loc[df['discoverymethod'] == 'Orbital Brightness Modulation']
df7= df.loc[df['discoverymethod'] == 'Astrometry']



Y3 = df3['pl_rade']
X3= df3['pl_orbper']

Y1 = df1['pl_rade']
X1= df1['pl_orbper']

Y2 = df2['pl_rade']
X2= df2['pl_orbper']

Y4 = df4['pl_rade']
X4= df4['pl_orbper']

Y5 = df5['pl_rade']
X5= df5['pl_orbper']

Y6 = df6['pl_rade']
X6= df6['pl_orbper']

Y7 = df7['pl_rade']
X7= df7['pl_orbper']



plt.scatter(X1,Y1,marker='.',color='red',label='Radial Velocity')
plt.scatter(X2,Y2,marker='o',color='blue',label='Transits')
plt.scatter(X3,Y3,marker='x',color='green',label='Microlensing')
plt.scatter(X4,Y4,marker='+',color='orange',label='Imaging')
plt.scatter(X5,Y5,marker='*',color='purple',label='Timimng Variations')
plt.scatter(X6,Y6,marker='.',color='black',label='Orbital Brightness Modulation')
plt.scatter(X7,Y7,marker='+',color='cyan',label='Astrometry')
plt.yscale(value='log')
plt.ylim(0.1,100)
plt.xlim(0.1,10**10)
plt.legend()
plt.xscale(value='log')
plt.title('Planet Radius v. Orbital Period')
plt.xlabel('Orbital Period [days]')
plt.ylabel('Planet Radius [Earth Radii]')
# Out:
# Text(0, 0.5, 'Planet Radius [Earth Radii]')

# %%
Y1 = df['sy_pnum']
Y2 = df['sy_snum']
X= df['disc_year']
plt.bar(X,Y1, label = 'planets', color = 'r')
plt.bar(X,Y2, label = 'stars', color = 'y')
plt.title('Discovery year vs No. of planets/stars found')
plt.xlabel('Discovery year')
plt.ylabel('Number of stars/planets found')
plt.legend()

# %%
Y3 = df3['sy_pnum']
X3= sum(df3['sy_pnum'])

Y1 = df1['sy_pnum']
X1= sum(df1['sy_pnum'])
Y2 = df2['sy_pnum']
X2= sum(df2['sy_pnum'])
Y4 = df4['sy_pnum']
X4= sum(df4['sy_pnum'])
Y5 = df5['sy_pnum']
X5= sum(df5['sy_pnum'])
Y6 = df6['sy_pnum']
X6= sum(df6['sy_pnum'])
Y7 = df7['sy_pnum']
X7= sum(df7['sy_pnum'])
X= [X1,X2,X3,X4,X5, X6, X7]
a = sum(X)
perc = []
for i in X:
    perc.append(round((i/a)*100,2))
perc
labels = [f'{l}, {s:0.1f}%' for l, s in zip(label1, perc)]
explode= (0.2 ,0 ,0 ,0, 0, 0, 0)
label1= ['Radial Velocity','Transits','Microlensing','Imaging','Timing Varitions','Orbital Brightness Modulation','Astrometry']
ax= plt.figure(figsize=(20,8))
ax=plt.pie(X,labels= None,explode=explode,shadow=True, startangle=90,)
plt.title('No. of planets discovered Using different Techniques')
plt.tight_layout()
plt.legend(labels=labels,loc='lower right')
plt.show()

# %%
Y3 = df3['sy_snum']
X3= sum(df3['sy_snum'])

Y1 = df1['sy_snum']
X1= sum(df1['sy_snum'])
Y2 = df2['sy_snum']
X2= sum(df2['sy_snum'])
Y4 = df4['sy_snum']
X4= sum(df4['sy_snum'])
Y5 = df5['sy_snum']
X5= sum(df5['sy_snum'])
Y6 = df6['sy_snum']
X6= sum(df6['sy_snum'])
Y7 = df7['sy_snum']
X7= sum(df7['sy_snum'])

X= [X1,X2,X3,X4,X5, X6, X7]

a = sum(X)
perc = []
for i in X:
    perc.append(round((i/a)*100,2))
perc
labels = [f'{l}, {s:0.1f}%' for l, s in zip(label1, perc)]

explode= (0.2 ,0 ,0 ,0, 0, 0, 0)
label1= ['Radial Velocity','Transits','Microlensing','Imaging','Timing Varitions','Orbital Brightness Modulation','Astrometry']
ax= plt.figure(figsize=(20,8))
ax=plt.pie(X,labels= None,explode=explode,shadow=True, startangle=90,)
plt.title('No. of planets discovered Using different Techniques')
plt.tight_layout()
plt.legend(labels=labels,loc='lower right')
plt.show()

# %%
Y3 = df3['pl_orbeccen']
X3= df3['pl_rade']

Y1 = df1['pl_orbeccen']
X1= df1['pl_rade']

Y2 = df2['pl_orbeccen']
X2= df2['pl_rade']

Y4 = df4['pl_orbeccen']
X4= df4['pl_rade']

Y5 = df5['pl_orbeccen']
X5= df5['pl_rade']

Y6 = df6['pl_orbeccen']
X6= df6['pl_rade']

Y7 = df7['pl_orbeccen']
X7= df7['pl_rade']



plt.scatter(X1,Y1,marker='.',color='red',label='Radial Velocity')
plt.scatter(X2,Y2,marker='o',color='blue',label='Transits')
plt.scatter(X3,Y3,marker='x',color='green',label='Microlensing')
plt.scatter(X4,Y4,marker='+',color='orange',label='Imaging')
plt.scatter(X5,Y5,marker='*',color='purple',label='Timimng Variations')
plt.scatter(X6,Y6,marker='.',color='black',label='Orbital Brightness Modulation')
plt.scatter(X7,Y7,marker='+',color='cyan',label='Astrometry')
plt.yscale(value='log')
plt.xscale(value='log')
plt.legend()
plt.title('Eccentricity v. Planet Radius')
plt.xlabel('Planet Radius [Earth Radii]')
plt.ylabel('Eccentricity')
# Out:
# Text(0, 0.5, 'Eccentricity')

# %%
Y = df['pl_bmasse']
X= df['pl_rade']
plt.scatter(X,Y,marker='.',color='cyan')
plt.yscale(value='log')
plt.xscale(value='log')
plt.title('PLanet Mass v. Planet Radius')
plt.xlabel('Planet Radius [Earth Radii]')
plt.ylabel('Planet Mass [Earth Mass]')
# Out:
# Text(0, 0.5, 'Planet Mass [Earth Mass]')

# %%
Y = df['pl_bmasse']/(4/3*3.14*df['pl_rade']*df['pl_rade']*df['pl_rade'])
X= df['pl_bmasse']
plt.scatter(X,Y,marker='.',color='green')
plt.yscale(value='log')
plt.xscale(value='log')
plt.title('PLanet Density v. Planet Mass')
plt.ylabel('Planet Density (g/cc)')
plt.xlabel('Planet Mass [Earth Mass]')
# Out:
# Text(0.5, 0, 'Planet Mass [Earth Mass]')

# %%
Y = df['pl_bmasse']/(4/3*3.14*df['pl_rade']*df['pl_rade']*df['pl_rade'])
X= df['pl_rade']
plt.scatter(X,Y,marker='.',color='purple')
plt.yscale(value='log')
plt.xscale(value='log')
plt.title('PLanet Density v. Planet Radius')
plt.ylabel('Planet Density (g/cc)')
plt.xlabel('Planet Radius [Earth Radii]')
# Out:
# Text(0.5, 0, 'Planet Radius [Earth Radii]')

# %%
Y = df['pl_eqt']
X= df['pl_rade']
plt.scatter(X,Y,marker='.',color='grey')
plt.yscale(value='log')
plt.xscale(value='log')
plt.title('Equilibrium Temprature v. Planet Radius')
plt.ylabel('Equilibrium Temprature(K)')
plt.xlabel('Planet Radius [Earth Radii]')
# Out:
# Text(0.5, 0, 'Planet Radius [Earth Radii]')

# %%
Y = df['pl_insol']
X= df['pl_rade']
plt.scatter(X,Y,marker='.',color='red')
plt.yscale(value='log')
plt.xscale(value='log')
plt.title('Insolation Flux v. Planet Radius')
plt.ylabel('Insolation Flux [Earth Flux]')
plt.xlabel('Planet Radius [Earth Radii]')
# Out:
# Text(0.5, 0, 'Planet Radius [Earth Radii]')

# %%
Y = df['st_logg']
X= df['pl_bmasse']
plt.scatter(X,Y,marker='.',color='blue')
plt.yscale(value='log')
plt.xscale(value='log')
plt.title('Surface Gravity v. Planet Mass')
plt.ylabel('Surface Gravity (log10(cm/s**2))')
plt.xlabel('Planet Mass [Earth Mass]')
# Out:
# Text(0.5, 0, 'Planet Mass [Earth Mass]')

# %% [markdown]
# Now Using Kepler Dataset which is a subset of Planetary Dataset used above in order to classify Habitable Candidates

# %% [markdown]
# Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# PLanetary Systems Data provided by Caltech-Nasa collab.
# https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PSCompPars
# https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=cumulative


df8 = pd.read_csv('exoplanets_new.csv')
print(df8.shape)
df8.head()
# Out:
# (9564, 49)
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0      1.000              0              0              0              0
# 1      0.969              0              0              0              0
# 2      0.000              0              0              0              0
# 3      0.000              0              1              0              0
# 4      1.000              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# ...

# %%
#Analysing Data
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              9564 non-null   int64
#  1   kepoi_name         9564 non-null   object
#  2   kepler_name        2673 non-null   object
#  3   koi_disposition    9564 non-null   object
#  4   koi_pdisposition   9564 non-null   object
#  5   koi_score          8054 non-null   float64
#  6   koi_fpflag_nt      9564 non-null   int64
#  7   koi_fpflag_ss      9564 non-null   int64
#  8   koi_fpflag_co      9564 non-null   int64
#  9   koi_fpflag_ec      9564 non-null   int64
#  10  koi_period         9564 non-null   float64
#  11  koi_period_err1    9110 non-null   float64
#  12  koi_period_err2    9110 non-null   float64
#  13  koi_time0bk        9564 non-null   float64
#  14  koi_time0bk_err1   9110 non-null   float64
#  15  koi_time0bk_err2   9110 non-null   float64
# ...

# %% [markdown]
# Renaming according to Column defined in Dataset

# %%
df8 = df8.rename(columns={'kepid':             'KepID',
'kepoi_name':        'KOI Name',
'kepler_name':       'Kepler Name',
'koi_disposition':   'Exoplanet Archive Disposition',
'koi_pdisposition':  'Disposition Using Kepler Data',
'koi_score':         'Disposition Score',
'koi_fpflag_nt':     'Not Transit-Like False Positive Flag',
'koi_fpflag_ss':     'Stellar Eclipse False Positive Flag',
'koi_fpflag_co':     'Centroid Offset False Positive Flag',
'koi_fpflag_ec':     'Ephemeris Match Indicates Contamination False Positive Flag',
'koi_period':        'Orbital Period [days]',
'koi_period_err1':   'Orbital Period Upper Unc. [days]',
'koi_period_err2':   'Orbital Period Lower Unc. [days]',
'koi_time0bk':       'Transit Epoch [BKJD]',
'koi_time0bk_err1':  'Transit Epoch Upper Unc. [BKJD]',
'koi_time0bk_err2':  'Transit Epoch Lower Unc. [BKJD]',
'koi_impact':        'Impact Parameter',
'koi_impact_err1':   'Impact Parameter Upper Unc.',
'koi_impact_err2':   'Impact Parameter Lower Unc.',
'koi_duration':      'Transit Duration [hrs]',
'koi_duration_err1': 'Transit Duration Upper Unc. [hrs]',
'koi_duration_err2': 'Transit Duration Lower Unc. [hrs]',
'koi_depth':         'Transit Depth [ppm]',
'koi_depth_err1':    'Transit Depth Upper Unc. [ppm]',
'koi_depth_err2':    'Transit Depth Lower Unc. [ppm]',
'koi_prad':          'Planetary Radius [Earth radii]',
'koi_prad_err1':     'Planetary Radius Upper Unc. [Earth radii]',
'koi_prad_err2':     'Planetary Radius Lower Unc. [Earth radii]',
'koi_teq':           'Equilibrium Temperature [K]',
'koi_teq_err1':      'Equilibrium Temperature Upper Unc. [K]',
'koi_teq_err2':      'Equilibrium Temperature Lower Unc. [K]',
'koi_insol':         'Insolation Flux [Earth flux]',
'koi_insol_err1':    'Insolation Flux Upper Unc. [Earth flux]',
'koi_insol_err2':    'Insolation Flux Lower Unc. [Earth flux]',
'koi_model_snr':     'Transit Signal-to-Noise',
'koi_tce_plnt_num':  'TCE Planet Number',
'koi_tce_delivname': 'TCE Delivery',
'koi_steff':         'Stellar Effective Temperature [K]',
'koi_steff_err1':    'Stellar Effective Temperature Upper Unc. [K]',
'koi_steff_err2':    'Stellar Effective Temperature Lower Unc. [K]',
'koi_slogg':         'Stellar Surface Gravity [log10(cm/s**2)]',
'koi_slogg_err1':    'Stellar Surface Gravity Upper Unc. [log10(cm/s**2)]',
'koi_slogg_err2':    'Stellar Surface Gravity Lower Unc. [log10(cm/s**2)]',
'koi_srad':          'Stellar Radius [Solar radii]',
'koi_srad_err1':     'Stellar Radius Upper Unc. [Solar radii]',
'koi_srad_err2':     'Stellar Radius Lower Unc. [Solar radii]',
'ra':                'RA [decimal degrees]',
'dec':               'Dec [decimal degrees]',
'koi_kepmag':        'Kepler-band [mag]'

})

# %%
df8.shape
df8.head()
# Out:
#       KepID   KOI Name   Kepler Name Exoplanet Archive Disposition  \
# 0  10797460  K00752.01  Kepler-227 b                     CONFIRMED
# 1  10797460  K00752.02  Kepler-227 c                     CONFIRMED
# 2  10811496  K00753.01           NaN                     CANDIDATE
# 3  10848459  K00754.01           NaN                FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b                     CONFIRMED
#
#   Disposition Using Kepler Data  Disposition Score  \
# 0                     CANDIDATE              1.000
# 1                     CANDIDATE              0.969
# 2                     CANDIDATE              0.000
# 3                FALSE POSITIVE              0.000
# 4                     CANDIDATE              1.000
#
#    Not Transit-Like False Positive Flag  Stellar Eclipse False Positive Flag  \
# 0                                     0                                    0
# 1                                     0                                    0
# ...

# %% [markdown]
# Coding Qualitative Data for Classfification

# %%
df8['ExoplanetCandidate'] = df8['Disposition Using Kepler Data'].apply(lambda x: 1 if x == 'CANDIDATE' else 0)
df8['ExoplanetConfirmed'] = df8['Exoplanet Archive Disposition'].apply(lambda x: 2 if x == 'CONFIRMED' else 1 if x == 'CANDIDATE' else 0 )
df8.head()
# Out:
#       KepID   KOI Name   Kepler Name Exoplanet Archive Disposition  \
# 0  10797460  K00752.01  Kepler-227 b                     CONFIRMED
# 1  10797460  K00752.02  Kepler-227 c                     CONFIRMED
# 2  10811496  K00753.01           NaN                     CANDIDATE
# 3  10848459  K00754.01           NaN                FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b                     CONFIRMED
#
#   Disposition Using Kepler Data  Disposition Score  \
# 0                     CANDIDATE              1.000
# 1                     CANDIDATE              0.969
# 2                     CANDIDATE              0.000
# 3                FALSE POSITIVE              0.000
# 4                     CANDIDATE              1.000
#
#    Not Transit-Like False Positive Flag  Stellar Eclipse False Positive Flag  \
# 0                                     0                                    0
# 1                                     0                                    0
# ...

# %% [markdown]
# Replacing empty values

# %%
missing_values=['??','na','X','999999']
df8=df8.replace(missing_values,np.NaN)
df8.shape
df8.head()
# Out:
#       KepID   KOI Name   Kepler Name Exoplanet Archive Disposition  \
# 0  10797460  K00752.01  Kepler-227 b                     CONFIRMED
# 1  10797460  K00752.02  Kepler-227 c                     CONFIRMED
# 2  10811496  K00753.01           NaN                     CANDIDATE
# 3  10848459  K00754.01           NaN                FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b                     CONFIRMED
#
#   Disposition Using Kepler Data  Disposition Score  \
# 0                     CANDIDATE              1.000
# 1                     CANDIDATE              0.969
# 2                     CANDIDATE              0.000
# 3                FALSE POSITIVE              0.000
# 4                     CANDIDATE              1.000
#
#    Not Transit-Like False Positive Flag  Stellar Eclipse False Positive Flag  \
# 0                                     0                                    0
# 1                                     0                                    0
# ...

# %%
df8.info()
df8.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 51 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   KepID                                                        9564 non-null   int64
#  1   KOI Name                                                     9564 non-null   object
#  2   Kepler Name                                                  2673 non-null   object
#  3   Exoplanet Archive Disposition                                9564 non-null   object
#  4   Disposition Using Kepler Data                                9564 non-null   object
#  5   Disposition Score                                            8054 non-null   float64
#  6   Not Transit-Like False Positive Flag                         9564 non-null   int64
# ...

# %% [markdown]
# To differentiate Confirmed Exoplanets and Kepler Candidates

# %%
df1= df8.loc[df8['ExoplanetConfirmed'] == 2]
df2= df8.loc[df8['ExoplanetCandidate'] == 1]

# %% [markdown]
# Plots

# %%
import matplotlib.pyplot as plt

# %%
Y1 = df1['Planetary Radius [Earth radii]']
X1= df1['Orbital Period [days]']
Y2 = df2['Planetary Radius [Earth radii]']
X2= df2['Orbital Period [days]']

plt.scatter(X2,Y2,marker='.',label='Kepler Candidates',color='red')
plt.scatter(X1,Y1,marker='.',label='Confirmed Planets',color='blue')

plt.legend()

plt.yscale(value='log')
plt.xscale(value='log')
plt.xlim(0.1, 10000)
plt.ylim(0.1,10**5)
plt.title('Radius(days) vs Orbital Period [days]')
plt.xlabel('Orbital Period [days]')
plt.ylabel('Planetary Radius [Earth radii]')
# Out:
# Text(0, 0.5, 'Planetary Radius [Earth radii]')

# %%
Y = df2['Planetary Radius [Earth radii]']
X= df2['Equilibrium Temperature [K]']

plt.scatter(X,Y,marker='.',color='red')


plt.yscale(value='log')
plt.xscale(value='linear')
plt.xlim(0, 6000)
plt.ylim(0.1,10**5)
plt.title('Kepler Radius - T_equiliblibrium Distribution ')
plt.xlabel('Equilibrium Temperature [K]')
plt.ylabel('Planetary Radius [Earth radii]')
# Out:
# Text(0, 0.5, 'Planetary Radius [Earth radii]')

# %%
Y = df2['Planetary Radius [Earth radii]']
X= df2['Transit Depth [ppm]']
plt.scatter(X,Y,marker='.',color='red')
plt.xscale(value='log')
plt.yscale(value='log')
plt.xlim(10,10**5)
plt.ylim(0.1,10**5)
plt.title('Kepler Radius - T_Depth Distribution ')
plt.xlabel('Transit Depth [ppm]')
plt.ylabel('Planetary Radius [Earth radii]')
# Out:
# Text(0, 0.5, 'Planetary Radius [Earth radii]')

# %% [markdown]
# Cleaning of Data

# %%
df8.isna().any()
# Out:
# KepID                                                          False
# KOI Name                                                       False
# Kepler Name                                                     True
# Exoplanet Archive Disposition                                  False
# Disposition Using Kepler Data                                  False
# Disposition Score                                               True
# Not Transit-Like False Positive Flag                           False
# Stellar Eclipse False Positive Flag                            False
# Centroid Offset False Positive Flag                            False
# Ephemeris Match Indicates Contamination False Positive Flag    False
# Orbital Period [days]                                          False
# Orbital Period Upper Unc. [days]                                True
# Orbital Period Lower Unc. [days]                                True
# Transit Epoch [BKJD]                                           False
# ...

# %%
import seaborn as sns
sns.heatmap(df8.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dropping colums with high correlation in order to avoid Dimensionality curse

# %%
df8.drop(columns=['Kepler Name','KOI Name','Disposition Score','Equilibrium Temperature Upper Unc. [K]',
                 'KepID','Exoplanet Archive Disposition','Disposition Using Kepler Data',
                 'Not Transit-Like False Positive Flag','Orbital Period Upper Unc. [days]','Orbital Period Lower Unc. [days]','Stellar Eclipse False Positive Flag','Centroid Offset False Positive Flag',
                 'Ephemeris Match Indicates Contamination False Positive Flag','TCE Delivery',
                 'Equilibrium Temperature Lower Unc. [K]','Transit Epoch Upper Unc. [BKJD]','Transit Epoch Lower Unc. [BKJD]','Impact Parameter','Impact Parameter Upper Unc.','Impact Parameter Lower Unc.','Transit Duration Upper Unc. [hrs]','Transit Duration Lower Unc. [hrs]','Transit Depth [ppm]','Transit Depth Upper Unc. [ppm]','Transit Depth Lower Unc. [ppm]','Kepler-band [mag]'], inplace=True)

# %% [markdown]
# Cleaning Function

# %%
df8.dropna(inplace=True)

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

clean_dataset(df8)
# Out:
#       Orbital Period [days]  Transit Epoch [BKJD]  Transit Duration [hrs]  \
# 0                  9.488036            170.538750                 2.95750
# 1                 54.418383            162.513840                 4.50700
# 2                 19.899140            175.850252                 1.78220
# 3                  1.736952            170.307565                 2.40641
# 4                  2.525592            171.595550                 1.65450
# ...                     ...                   ...                     ...
# 9559               0.527699            131.705093                 3.22210
# 9560               1.739849            133.001270                 3.11400
# 9561               0.681402            132.181750                 0.86500
# 9562             333.486169            153.615010                 3.19900
# 9563               4.856035            135.993300                 3.07800
#
#       Planetary Radius [Earth radii]  \
# 0                               2.26
# ...

# %% [markdown]
# Models

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error, precision_score, confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
features = df8.drop(columns=['Planetary Radius [Earth radii]','Equilibrium Temperature [K]','Stellar Surface Gravity [log10(cm/s**2)]','ExoplanetCandidate','ExoplanetConfirmed'])
target = df8.ExoplanetCandidate

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=1, test_size=.40)

# %%
def evaluation(y_true, y_pred):
    print('Evaluation Metrics:')
    print('Accuracy: ' + str(metrics.accuracy_score(y_test, y_pred)))
    print('Recall: ' + str(metrics.recall_score(y_test, y_pred)))
    print('F1 Score: ' + str(metrics.f1_score(y_test, y_pred)))
    print('Precision: ' + str(metrics.precision_score(y_test, y_pred)))

# %%
lr = LogisticRegression(C=100, max_iter=100000, class_weight='balanced')
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
evaluation(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Accuracy: 0.7770232031692134
# Recall: 0.8112359550561797
# F1 Score: 0.7856365614798694
# Precision: 0.7616033755274262

# %%
forest = RandomForestClassifier(n_estimators=1000, criterion='gini')
forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)
evaluation(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Accuracy: 0.8486134691567628
# Recall: 0.8550561797752809
# F1 Score: 0.850516904163174
# Precision: 0.8460255697609783
